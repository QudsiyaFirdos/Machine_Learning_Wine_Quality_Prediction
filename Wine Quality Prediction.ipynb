# %% [markdown]
# # Wine Quality Prediction

# %% [markdown]
# Import libraries

# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Load the dataset

# %% [markdown]
# Adjust the path to your CSV file

# %%
path = r"C:\Users\QFAROOQU\Downloads\winequalityN.csv"
df = pd.read_csv(path)

# %%
df.head
# Out:
# <bound method NDFrame.head of        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
# ...

# %% [markdown]
# Drop the 'type' column

# %%
df=df.drop(columns=['type'])

# %% [markdown]
# Define features and target

# %%
X = df.drop(columns=['quality'])
y = df['quality']

# %% [markdown]
# Split the data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2020)

# %% [markdown]
# Feature Scaling

# %%
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %% [markdown]
#  Initialize and train the Random Forest model

# %%
classifier = RandomForestClassifier(n_estimators=100, random_state=2020)
classifier.fit(X_train_sc, y_train)
# Out:
# RandomForestClassifier(random_state=2020)

# %% [markdown]
# Evaluate the model

# %%
print("Model accuracy:", classifier.score(X_test_sc, y_test))
# Out:
# Model accuracy: 0.7

# %% [markdown]
#  Predicting for a new wine sample

# %% [markdown]
# Create a DataFrame for the new sample with the same feature names

# %%
wine_data = {
    'fixed acidity': [7.4], 'volatile acidity': [0.70], 'citric acid': [0.00], 'residual sugar': [1.9],
    'chlorides': [0.076], 'free sulfur dioxide': [11.0], 'total sulfur dioxide': [34.0], 'density': [0.9978],
    'pH': [3.51], 'sulphates': [0.56], 'alcohol': [9.4]
}
wine_sample = pd.DataFrame(wine_data, columns=X.columns)
wine_sample_array = wine_sample.to_numpy()

# %% [markdown]
# Predict

# %%
pred = classifier.predict(wine_sample_array)

# %%
print(f'Predicted quality for the new wine sample: {pred[0]}')
# Out:
# Predicted quality for the new wine sample: 6
